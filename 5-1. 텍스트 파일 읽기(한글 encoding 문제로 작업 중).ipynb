# %% [markdown]
# * 텍스트 파일 읽기

# %%
import pandas as pd

# %%
Titanic6 = pd.read_csv('/content/drive/MyDrive/data/Titanic/train.csv', usecols=['Name', 'Sex', 'Age', 'SibSp', 'Parch']) # usecols로 일부 열만 읽어옴

# %%
print(Titanic6)
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch
# 0        0
# 1        0
# 2        0
# ...

# %%
Titanic7 = pd.read_csv('/content/drive/MyDrive/data/Titanic/train.csv')

# %%
Titanic7.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
Titanic7.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Titanic7(train.loc['Braund, Mr. Owen Harris']) # Name 열은 인덱스로 사용할 열로 지정되지 않음
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4510be3cc9b4> in <module>()
# ----> 1 Titanic7(train.loc['Braund, Mr. Owen Harris'])
#
# TypeError: 'DataFrame' object is not callable

# %%
Titanic7 = pd.read_csv('/content/drive/MyDrive/data/Titanic/train.csv', index_col='Name') # Name을 인덱스로 사용할 열로 지정

# %%
print(Titanic7.loc['Braund, Mr. Owen Harris'])
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df0 = pd.read_csv('/content/drive/MyDrive/data/Python/score.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-9e16a1ba6c2b> in <module>()
# ----> 1 df0 = pd.read_csv('/content/drive/MyDrive/data/Python/score.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/data/Python/score.txt', encoding='utf-8')

# %%
df2 = pd.read_csv('/content/drive/MyDrive/data/Python/score.csv', header=0, sep='',encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-89b59a643826> in <module>()
# ----> 1 df2 = pd.read_csv('/content/drive/MyDrive/data/Python/score.csv', header=0, sep='',encoding='cp949')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df3 = pd.read_csv('/content/drive/MyDrive/data/Python/score.txt', header=0, sep='',encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9aa4f818a43a> in <module>()
# ----> 1 df3 = pd.read_csv('/content/drive/MyDrive/data/Python/score.txt', header=0, sep='',encoding='euc-kr')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print(df1.head(3))

# %%
print(df2.head(3))

# %%
print(df3.tail(3))

# %%
print(type(df1))

# %%
df4 = pd.read_csv('/content/drive/MyDrive/data/Python/score.txt', skiprows=1,encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-9-2f666412dd13> in <module>()
# ----> 1 df4 = pd.read_csv('/content/drive/MyDrive/data/Python/score.txt', skiprows=1,encoding='euc-kr')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
