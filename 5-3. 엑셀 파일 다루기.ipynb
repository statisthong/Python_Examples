# %%
import pandas as pd

# %%
data = pd.read_excel(r'/content/drive/MyDrive/data/Python/height.xlsx', header=None, names=['height', 'gender'])

# %%
data
# Out:
#    height gender
# 0     170      M
# 1     175      M
# 2     182      M
# 3     168      F
# 4     162      F
# 5     158      F

# %%
df1 = pd.DataFrame(data)

# %%
df1.head()
# Out:
#    height gender
# 0     170      M
# 1     175      M
# 2     182      M
# 3     168      F
# 4     162      F

# %%
print(df1)
# Out:
#    height gender
# 0     170      M
# 1     175      M
# 2     182      M
# 3     168      F
# 4     162      F
# 5     158      F

# %%
data = pd.read_excel('http://jupiter.hallym.ac.kr/ftpdata/data/bmi.xlsx', index_col=2)

# %%
df2 = pd.DataFrame(data)

# %%
print(df2)
# Out:
#         키  몸무게  종교 성별 결혼여부
# 출생년도
# 1974  167   68  No  F    N
# 1974  162   49  C2  F    N
# 1978  158   50  C2  F    N
# 1977  165   56  No  F    N
# 1959  160   52  No  F    N
# ...   ...  ...  .. ..  ...
# 1982  164   50  No  F    N
# 1979  163   52  No  F    Y
# 1979  160   56  C2  F    N
# 1974  160   49  No  F    N
# 1980  166   54  No  F    N
#
# [177 rows x 5 columns]

# %%
cars = {'make': ['Hyudai','Kia', 'Ford', 'Chevrolet'],
        'model': ['Sonata','K5', 'Taurus', 'Impala'],
        'price' : [3200,3100,3500,3700]}

# %%
df3 = pd.DataFrame(cars)

# %%
print(df3)
# Out:
#         make   model  price
# 0     Hyudai  Sonata   3200
# 1        Kia      K5   3100
# 2       Ford  Taurus   3500
# 3  Chevrolet  Impala   3700

# %%
export_excel = df3.to_excel(r'C:\Python\cars.xlsx', index=None, header=True)

# %%
export_excel = df3.to_excel('/content/drive/MyDrive/data/Python/cars.xlsx', index=None, header=True)
