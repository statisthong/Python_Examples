# %%
a = "abc"

# %%
a
# Out:
# 'abc'

# %%
print(len(a))
# Out:
# 3

# %%
x,y,z = a # x,y,z = 'abc'

# %%
x,y,z = 'abc'

# %%
print(x)
# Out:
# a

# %%
y

# %%
z
# Out:
# 'c'

# %%
# string.split(sep, max) # sep : 분리기준인 문자, max : 분리할 최대 횟수

# %%
bb = 'A test string'

# %%
blist0 = bb.split() # 빈칸 기준으로 분리하여 3개의 원소를 갖는 리스트가 얻어짐

# %%
blist0
# Out:
# ['A', 'test', 'string']

# %%
blist1 = bb.split('i') # 'i' 를 기준으로 분리하여 2개의 원소를 가짐

# %%
blist1
# Out:
# ['A test str', 'ng']

# %%
print(blist0, blist1)
# Out:
# ['A', 'test', 'string'] ['A test str', 'ng']

# %%
aa = a + "ABC" # a = "abc"

# %%
print(aa)
# Out:
# abcABC

# %%
aaa = a * 3 # a = "abc" 문자열 3번 반목

# %%
print(aaa)
# Out:
# abcabcabc
