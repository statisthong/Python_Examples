# %%
import datetime as dt

# %%
now = dt.datetime.now()

# %%
print(now.year)
# Out:
# 2022

# %%
print(now.strftime("%Y-%m-%d: %A"))
# Out:
# 2022-08-01: Monday

# %%
dob1 = dt.datetime(2000, 5, 17)

# %%
age = now.year - dob1.year

# %%
age
# Out:
# 22
