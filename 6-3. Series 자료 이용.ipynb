# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
s1 = Series([1.0, 2, 3]); s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
s1 - 2
# Out:
# 0   -1.0
# 1    0.0
# 2    1.0
# dtype: float64

# %%
sa = Series([1.0, 2, 3], index=['a', 'b', 'c'])

# %%
sc = Series([0.0, 1, 2], index=['a', 'b', 'd'])

# %%
sn = Series([1,2,1,3,3,5,3,4])

# %%
sa
# Out:
# a    1.0
# b    2.0
# c    3.0
# dtype: float64

# %%
sc
# Out:
# a    0.0
# b    1.0
# d    2.0
# dtype: float64

# %%
sn
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# 4    3
# 5    5
# 6    3
# 7    4
# dtype: int64

# %%
sac = sa+sc; sac
# Out:
# a    1.0
# b    3.0
# c    NaN
# d    NaN
# dtype: float64

# %%
sac.isnull()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
sac.notnull()
# Out:
# a     True
# b     True
# c    False
# d    False
# dtype: bool

# %%
sac.fillna(-1.0)
# Out:
# a    1.0
# b    3.0
# c   -1.0
# d   -1.0
# dtype: float64

# %%
sx=sac.dropna(); sx
# Out:
# a    1.0
# b    3.0
# dtype: float64

# %%
sc.__class__
# Out:
# pandas.core.series.Series

# %%
type(sc)
# Out:
# pandas.core.series.Series

# %%
sc[:2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
sy=sx.append(sc[:2]); sy
# Out:
# a    1.0
# b    3.0
# a    0.0
# b    1.0
# dtype: float64

# %%
sy.drop('a')
# Out:
# b    3.0
# b    1.0
# dtype: float64

# %%
sy.head()
# Out:
# a    1.0
# b    3.0
# a    0.0
# b    1.0
# dtype: float64

# %%
sy.tail(2)
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
sy.unique()
# Out:
# array([1., 3., 0.])

# %%
sy.nunique()
# Out:
# 3

# %%
sn.head()
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# 4    3
# dtype: int64

# %%
sn.describe()
# Out:
# count    8.00000
# mean     2.75000
# std      1.38873
# min      1.00000
# 25%      1.75000
# 50%      3.00000
# 75%      3.25000
# max      5.00000
# dtype: float64

# %%
list(sn.unique()) unique 한 값들
# Out:
# [1, 2, 3, 5, 4]

# %%
sn.nunique() # unique한 값의 개수
# Out:
# 5

# %%
sn.replace([1,2],0) # 1,2를 0으로 교체
# Out:
# 0    0
# 1    0
# 2    0
# 3    3
# 4    3
# 5    5
# 6    3
# 7    4
# dtype: int64
