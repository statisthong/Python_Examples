# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
plt.ion()

# %%
import numpy as np
x = np.linspace(0, 2, 100)

# %%
plt.figure()

# %%
plt.plot(x, x, label='linear')

# %%
plt.plot(x, x**2, label='quadratic')

# %%
plt.plot(x, x**3, label='cubic')

# %%
plt.xlim(-0.25, 2.25)
# Out:
# (-0.25, 2.25)

# %%
plt.yticks([0,1,2,4,8])
# Out:
# ([<matplotlib.axis.YTick at 0x7f54a398d5d0>,
#   <matplotlib.axis.YTick at 0x7f54a3993650>,
#   <matplotlib.axis.YTick at 0x7f54a3a15450>,
#   <matplotlib.axis.YTick at 0x7f54a3abecd0>,
#   <matplotlib.axis.YTick at 0x7f54a3a354d0>],
#  <a list of 5 Text major ticklabel objects>)

# %%
plt.xlabel('x label')
# Out:
# Text(0.5, 0, 'x label')

# %%
plt.xlabel('y label')
# Out:
# Text(0.5, 0, 'y label')

# %%
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.grid(True)

# %%
plt.text(1.6, 7, r'$y=x^3$')
# Out:
# Text(1.6, 7, '$y=x^3$')

# %%
plt.text(1.9, 4.5, r'$y=x^2$')
# Out:
# Text(1.9, 4.5, '$y=x^2$')

# %%
plt.text(1.9, 1.4, r'$y=x$')
# Out:
# Text(1.9, 1.4, '$y=x$')

# %%
plt.title("Simple Polynomials")
# Out:
# Text(0.5, 1.0, 'Simple Polynomials')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
